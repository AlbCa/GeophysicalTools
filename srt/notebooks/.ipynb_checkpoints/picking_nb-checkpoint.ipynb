# %% [markdown]
# # The picking notebook
# This routine aims to process a shot gather in order to extract the first arrival times
#
# **Author:** Alberto Carrera

# %% [markdown]
# ## 1. Import Libraries and Load Data
#
# Load data from SEG2, SEGY, or DAT files using SWAutils.
#
# Extract:
# - Seismic data array (`nsamples × ntraces`)
# - Sampling interval (`SR`)
# - Receiver positions (`x`)

# %%
import matplotlib.pyplot as plt
import SWAutils as swa
import numpy as np

filename = "Shot1.dat"
#filename = input("Enter the filename {}:")
datadir = "../data/"  # Folder path for data
figdir = '../figures/'

# Load seismic stream
data, SR, x = swa.load_stream(filename, datadir)

#print(f"Receiver positions (m): {x}")
print(f"Shot gather dimensions: {data.shape}")
print(f"Sampling rate: {SR} s")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import SWAutils as swa
#       3 import numpy as np
#       5 filename = "Shot1.dat"
#
# File ~/Documents/UNIPD/ESERCITAZIONI/GeophysicalMethods/srt/notebooks/SWAutils.py:9
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 from obspy import read
#      10 import matplotlib.pyplot as plt
#      11 from matplotlib.axes import Axes
#
# ModuleNotFoundError: No module named 'obspy'

# %% [markdown]
# ## 2. Data Visualization
#
# ### 2a. Wiggle Plot
# Plot normalized traces with offsets and filled positive/negative amplitudes.

# %%
fig, ax = plt.subplots(figsize=(7, 4))
swa.wiggle(swa.normit(data), SR=SR, xx=x, ax=ax)
ax.set_title(filename)
ax.set_ylim(0.6, 0)
plt.show()

#data = np.fliplr(data)

# %% [markdown]
# ## 3. Interactive Fisrt Arrivals Picking
# Pick the first arrival time at each channel

# %%
# ## 3. Interactive First Arrival Picking
import matplotlib
matplotlib.use('TkAgg')  # per interattività locale (puoi togliere se usi notebook con widget)

fig, ax = plt.subplots(figsize=(10, 6))
ax.imshow(swa.normit(data),
          extent=[x[0], x[-1], tt[-1], tt[0]],
          aspect='auto', cmap='gray', vmin=-1, vmax=1)
ax.set_xlabel("Offset [m]")
ax.set_ylabel("Time [s]")
ax.set_title("Click on first arrivals (press ENTER when done)")

plt.ion()
picks = plt.ginput(-1, timeout=0)
plt.ioff()

# %%
# %matplotlib inline

fig, ax = plt.subplots(figsize=(6.5, 5))
ax.plot(x_pick, t_pick, 'r.', label="First arrivals")
ax.legend()
plt.show()
# Out:
# Click on maxima and press ENTER when done:
# Selected points: [(0.23477493486504364, 21.42857142857143), (0.47123889803846886, 29.545454545454547), (0.6536539553436826, 36.36363636363637), (0.9728803056278068, 45.129870129870135)]

# %% [markdown]
# ## 4. Extract and Save
# Generate .txt file from picked points.
# Save both figure and data table for further analysis.

# %%
# Convert to arrays
picks = np.array(picks)
x_pick = picks[:, 0]
t_pick = picks[:, 1]

# ## 4. Save Picks

pick_df = pd.DataFrame({'Receiver_x(m)': x_pick, 'Time_s': t_pick})
out_path = os.path.join(outdir, filename[:-4] + "_picks.csv")
pick_df.to_csv(out_path, index=False)
print(f"✅ Picks saved to: {out_path}")


# ## 5. Quick Visualization of Picked Travel Times
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(x_pick, t_pick, 'ro-', markersize=4)
ax.set_xlabel("Offset [m]")
ax.set_ylabel("First arrival time [s]")
ax.set_title("Travel time curve")
ax.grid(True, linestyle=':')
plt.show()
# Out:
# 📁 Dispersion curve will be saved in: ../data/disp_curves/Shot1
#     freq(Hz)   V_ph(m/s)
# 0  21.428571  573.484070
# 1  21.945638  551.911000
# 2  22.462705  532.791393
# 3  22.979772  515.729227
# 4  23.496838  500.409360
