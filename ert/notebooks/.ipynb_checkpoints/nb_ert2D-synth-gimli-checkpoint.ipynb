# %% [markdown]
# # 2D ERT modelling and inversion

# %%
import matplotlib.pyplot as plt
import numpy as np

import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert

# %% [markdown]
# ## Geometry definition
# Create geometry definition for the modelling domain. ``worldMarker=True``
# indicates the default boundary conditions for the ERT

# %%
world = mt.createWorld(start=[-50, 0], end=[90, -50], #layers=[-1, -5],
                       worldMarker=True)
pg.show(world)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>, None)

# %% [markdown]
# Create some heterogeneous circular anomaly

# %%
block = mt.createCircle(pos=[10, -3.], radius=[2, 1], marker=4,
                        boundaryMarker=10, area=0.1)

# %%
poly = mt.createPolygon([(30,-6), (32,-3.5), (34,-4), (35,-4),
                         (38,-5), (35,-5.5), (33,-6.5)], isClosed=True,
                         addNodes=3, interpolate='spline', marker=5)

# %% [markdown]
# Merge geometry definition into a Piecewise Linear Complex (PLC)

# %%
geom = world + block + poly

# %% [markdown]
# Optional: show the geometry

# %%
pg.show(geom)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>, None)

# %% [markdown]
# ## Synthetic data generation
# Create a Dipole Dipole ('dd') measuring scheme with 21 electrodes.

# %%
seq_name = 'dd48_0_4'
scheme = pg.load('data/'+seq_name+'.dat') # pick up the scheme to reproduce
#elecs2D = np.genfromtxt('../../data/2d/elecs72surf.csv', delimiter=",",skip_header=1)
#data2D = pg.load(datadir + '../../data/2d/2Ddata.dat') # pick up the scheme to reproduce
print(scheme)
# Out:
# Data: Sensors: 48 data: 4320, nonzero entries: ['a', 'b', 'm', 'n', 'valid']

# %% [markdown]
# Put all electrode (aka sensors) positions into the PLC to enforce mesh
# refinement. Due to experience, its convenient to add further refinement
# nodes in a distance of 10% of electrode spacing to achieve sufficient
# numerical accuracy.

# %%
for p in scheme.sensors():
    geom.createNode(p)
    geom.createNode(p - [0, 0.1])

# Create a mesh for the finite element modelling with appropriate mesh quality.
mesh = mt.createMesh(geom, quality=34)

# Create a map to set resistivity values in the appropriate regions
# [[regionNumber, resistivity], [regionNumber, resistivity], [...]
rhomap = [[1, 400.],
          [4, 20.],
          [5, 100.],
          #[4, 150.],
          #[5, 25]
         ]

# Take a look at the mesh and the resistivity distribution
pg.show(mesh, data=rhomap, label=pg.unit('res'), showMesh=True)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>,
#  <matplotlib.colorbar.Colorbar at 0x72943f6f5bd0>)

# %% [markdown]
# Perform the modelling with the mesh and the measuring scheme itself
# and return a data container with apparent resistivity values,
# geometric factors and estimated data errors specified by the noise setting.
# The noise is also added to the data. Here 1% plus 1µV.
# Note, we force a specific noise seed as we want reproducable results for
# testing purposes.

# %%
data = ert.simulate(mesh, scheme=scheme, res=rhomap, noiseLevel=1,
                    noiseAbs=1e-6, seed=1337)

pg.info(np.linalg.norm(data['err']), np.linalg.norm(data['rhoa']))
pg.info('Simulated data', data)
pg.info('The data contains:', data.dataMap().keys())

pg.info('Simulated rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))
pg.info('Selected data noise %(min/max)', min(data['err'])*100, max(data['err'])*100)
# Out:
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Calculate geometric factors.
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Data error estimate (min:max)  0.010000008099037689 : 0.010793468410550526
# ModellingBase::setMesh() copying new mesh ... Found datafile: 48 electrodes
# Found: 48 free-electrodes
# rMin = 0.5, rMax = 94
# NGauLeg + NGauLag for inverse Fouriertransformation: 13 + 4
# Found non-Neumann domain
# 0.0150771 s
# FOP updating mesh dependencies ... 2.425e-06 s
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100
# Obtaining geometric factors (analytical)
# Calculating response for model: min = 20 max = 400
# Allocating memory for primary potential...... 0.00148147
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.235872s
# Response: min = 114.887 max = 458.959 mean = 351.206
# Reciprocity rms(modelReciprocity) 0.252723%, max: 1.40704%
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - 0.6607768224294323 23389.808277559605
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Simulated data Data: Sensors: 48 data: 4320, nonzero entries: ['a', 'b', 'err', 'k', 'm', 'n', 'rhoa', 'valid']
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - The data contains: ['a', 'b', 'err', 'i', 'ip', 'iperr', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Simulated rhoa (min/max) 115.04900725358647 462.41695000629926
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Selected data noise %(min/max) 1.000000809903769 1.0793468410550526

# %% [markdown]
# Optional: you can filter all values and tokens in the data container.
# Its possible that there are some negative data values due to noise and
# huge geometric factors. So we need to remove them.

# %%
data.remove(data['rhoa'] < 0)
pg.info('Filtered rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))

# You can save the data for further use
data.save(seq_name+'_fwd.dat')

# You can take a look at the data
ert.show(data)
# Out:
# 04/08/25 - 11:55:13 - pyGIMLi - INFO - Filtered rhoa (min/max) 115.04900725358647 462.41695000629926
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x72943fe35b90>)

# %% [markdown]
# ## Inversion with the ERTManager
# Initialize the ERTManager, e.g. with a data container or a filename.

# %%
mgr = ert.ERTManager(seq_name+'_fwd.dat')

# %% [markdown]
# Run the inversion with the preset data. The Inversion mesh will be created
# with default settings.

# %%
inv = mgr.invert(lam=20, verbose=True)
#np.testing.assert_approx_equal(mgr.inv.chi2(), 0.7, significant=1)
# Out:
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Found 2 regions.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Found 2 regions.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2222 Cells: 4164 Boundaries: 3262
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Use median(data values)=361.8299476668125
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Created startmodel from forward operator:780, min/max=361.829948/361.829948
# 04/08/25 - 11:55:16 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 103
#   Input segments: 104
#   Input holes: 0
#
#   Mesh vertices: 591
#   Mesh triangles: 1041
#   Mesh edges: 1631
#   Mesh exterior boundary edges: 139
#   Mesh interior boundary edges: 20
#   Mesh subsegments (constrained edges): 159
#
# min/max(dweight) = 92.6486/99.9999
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x72944730ebb0>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 115/462
# min/max (error): 1%/1.08%
# min/max (start model): 362/362
# --------------------------------------------------------------------------------
# Calculating response for model: min = 361.83 max = 361.83
# Allocating memory for primary potential...... 0.00242592
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.352735s
# Response: min = 359.359 max = 362.301 mean = 361.669
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 92.6486/99.9999
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1110 x 780
# check Jacobian: wrong dimensions: (0x0) should be (4320x780)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.011775:time: 5.45166s
# inv.iter 0 ... chi² =  344.84
# --------------------------------------------------------------------------------
# sens sum: median = 1.03665 min = 0.566367 max = 1.48432
# ... 5.46262 s
# min data = 115.049 max data = 462.417 (4320)
# min error = 0.01 max error = 0.0107935 (4320)
# min response = 359.359 max response = 362.301 (4320)
# calc without reference model
# 0: rms/rrms(data, response) = 58.5309/23.1101%
# 0: chi^2(data, response, error, log) = 344.84
# 0: Phi = 1.48971e+06 + 0 * 20 = 1.48971e+06
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 15.1289 max = 723.697
# Using existing primary potentials.
# Forward: time: 0.299385s
# Found neg. resp (saving).
# 172 -0.937612 9.46522
# 1 6 4 9
# Response: min = -140.153 max = 480.28 mean = 334.7
# Reciprocity rms(modelReciprocity) 5.47679%, max: 243.98%
# 1: LS newModel: min = 15.1289; max = 723.697
# 1: LS newResponse: min = 2.97904; max = 480.066
# 1: rms/rrms(data, LS newResponse) = 36.1821/11.8623%
# 1: chi^2(data, LS newResponse, error, log) = 243.197
# 1: Phi = 1.05061e+06+48.8912*20=1.05159e+06
# Performing line search with tau = 0.56
# chi² =   47.90 (dPhi = 86.09%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... Calculating response for model: min = 61.1553 max = 533.45
# Using existing primary potentials.
# Forward: time: 0.319232s
# Response: min = 89.7975 max = 418.876 mean = 348.017
# Reciprocity rms(modelReciprocity) 0.630409%, max: 22.4696%
# 1: Model: min = 61.1553; max = 533.45
# 1: Response: min = 100.523; max = 418.779
# 1: rms/rrms(data, Response) = 21.6956/7.3097%
# 1: chi^2(data, Response, error, log) = 47.8979
# 1: Phi = 206919+15.3323*20=207226
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.0035872:time: 7.78915s
# sens sum: median = 1.06365 min = 0.555352 max = 1.53992
# ... 7.80281 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 27.8985 max = 537.246
# Using existing primary potentials.
# Forward: time: 0.294478s
# Response: min = 104.602 max = 465.313 mean = 350.772
# Reciprocity rms(modelReciprocity) 0.280705%, max: 5.23873%
# Performing line search with tau = 0.99
# 2: Model: min = 27.8985; max = 537.246
# 2: Response: min = 107.378; max = 464.782
# 2: rms/rrms(data, Response) = 4.65932/1.44202%
# 2: chi^2(data, Response, error, log) = 2.09224
# 2: Phi = 9038.47+22.7754*20=9493.98
# chi² =    2.09 (dPhi = 95.42%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00582094:time: 7.65627s
# chi² =    1.03 (dPhi = 48.82%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... sens sum: median = 1.0864 min = 0.47879 max = 2.42939
# ... 7.67091 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 28.357 max = 543.377
# Using existing primary potentials.
# Forward: time: 0.286643s
# Response: min = 112.539 max = 457.645 mean = 350.764
# Reciprocity rms(modelReciprocity) 0.257627%, max: 4.40777%
# 3: LS newModel: min = 28.357; max = 543.377
# 3: LS newResponse: min = 115.047; max = 457.043
# 3: rms/rrms(data, LS newResponse) = 3.71676/1.05145%
# 3: chi^2(data, LS newResponse, error, log) = 1.09223
# 3: Phi = 4718.42+21.31*20=5144.62
# Performing line search with tau = 0.8
# Calculating response for model: min = 28.2647 max = 542.145
# Using existing primary potentials.
# Forward: time: 0.2954s
# Response: min = 112.049 max = 457.107 mean = 350.773
# Reciprocity rms(modelReciprocity) 0.237698%, max: 3.05133%
# 3: Model: min = 28.2647; max = 542.145
# 3: Response: min = 113.503; max = 456.79
# 3: rms/rrms(data, Response) = 3.57402/1.017%
# 3: chi^2(data, Response, error, log) = 1.02528
# 3: Phi = 4429.21+21.5005*20=4859.22
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00386571:time: 7.93849s
# sens sum: median = 1.08482 min = 0.460332 max = 2.42039
# ... 7.95195 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 27.7007 max = 545.242
# Using existing primary potentials.
# Forward: time: 0.28769s
# Response: min = 111.989 max = 460.134 mean = 350.71
# Reciprocity rms(modelReciprocity) 0.287989%, max: 6.11792%
# 4: LS newModel: min = 27.7007; max = 545.242
# 4: LS newResponse: min = 115.468; max = 459.951
# 4: rms/rrms(data, LS newResponse) = 3.68447/1.05537%
# 4: chi^2(data, LS newResponse, error, log) = 1.10256
# 4: Phi = 4763.05+21.5434*20=5193.92
# Performing line search with tau = 0.36
# chi² =    0.99 (dPhi = 3.29%) lam: 20.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.99)                   #
# ################################################################################
# Calculating response for model: min = 28.0604 max = 543.258
# Using existing primary potentials.
# Forward: time: 0.424382s
# Response: min = 112.008 max = 458.206 mean = 350.756
# Reciprocity rms(modelReciprocity) 0.252024%, max: 3.8665%
# 4: Model: min = 28.0604; max = 543.258
# 4: Response: min = 114.195; max = 457.937
# 4: rms/rrms(data, Response) = 3.51961/0.998872%
# 4: chi^2(data, Response, error, log) = 0.988305
# 4: Phi = 4269.48+21.4932*20=4699.34

# %% [markdown]
# Let the ERTManger show you the model of the last successful run and how it
# fits the data. Shows data, model response, and model.

# %%
mgr.showResultAndFit()
meshPD = pg.Mesh(mgr.paraDomain) # Save copy of para mesh for plotting later

# %% [markdown]
# You can also provide your own mesh (e.g., a structured grid if you like them)
# Note, that x and y coordinates needs to be in ascending order to ensure that
# all the cells in the grid have the correct orientation, i.e., all cells need
# to be numbered counter-clockwise and the boundary normal directions need to
# point outside.

# %%
inversionDomain = pg.createGrid(x=np.linspace(start=0, stop=47*1, num=48),
                                y=-pg.cat([0], pg.utils.grange(0.5, 10, n=5))[::-1],
                                marker=2)

# %% [markdown]
# ## Inversion with custom mesh
# The inversion domain for ERT problems needs a boundary that represents the
# far regions in the subsurface of the halfspace.
# Give a cell marker lower than the marker for the inversion region, the lowest
# cell marker in the mesh will be the inversion boundary region by default.

# %%
grid = pg.meshtools.appendTriangleBoundary(inversionDomain, marker=1,
                                           xbound=50, ybound=50)
pg.show(grid, markers=True)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>,
#  <matplotlib.colorbar.Colorbar at 0x729446a09810>)

# %%
data.remove(data["rhoa"] <= 200)
data.remove(data["rhoa"] >= 800)
data.removeInvalid()
data.removeUnusedSensors()

# plot
fig, ax = plt.subplots(figsize=(6, 3))
ax.scatter(np.arange(1, len(data['a']) + 1), data["rhoa"], color='red', s=10)
ax.set_ylabel('Apparent Resistivity (ohm.m)')
ax.set_xlabel('measure n.')
fig.suptitle(f'Quadrupoles n :{len(data["rhoa"])}')
# Out:
# Text(0.5, 0.98, 'Quadrupoles n :4283')

# %% [markdown]
# The Inversion can be called with data and mesh as argument as well

# %%
model = mgr.invert(data, mesh=grid, lam=20, verbose=True)
# Out:
# 04/08/25 - 11:56:26 - pyGIMLi - INFO - Found 2 regions.
# 04/08/25 - 11:56:26 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 04/08/25 - 11:56:26 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 04/08/25 - 11:56:27 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 04/08/25 - 11:56:27 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2079 Cells: 3068 Boundaries: 2610
# 04/08/25 - 11:56:27 - pyGIMLi - INFO - Use median(data values)=362.4123107113839
# 04/08/25 - 11:56:27 - pyGIMLi - INFO - Created startmodel from forward operator:235, min/max=362.412311/362.412311
# 04/08/25 - 11:56:27 - pyGIMLi - INFO - Starting inversion.
# Found datafile: 48 electrodes
# Found: 48 node-electrodes
# Found non-Neumann domain
#  updateDataDependency:: cleaning primpot
# Reset region parameter
# RegionManager copying mesh ...0.00378985 s
# create NeighborInfos ... 2.0667e-05 s
# analysing mesh ... 2 regions.
# creating para domain ... 0.00138383 s
# creating para domain ... 0.0013746 s
# ModellingBase::setMesh() copying new mesh ... Found datafile: 48 electrodes
# Found: 48 free-electrodes
# Found non-Neumann domain
# 0.0308447 s
# FOP updating mesh dependencies ... 1.332e-05 s
# ModellingBase::setMesh() copying new mesh ... 0.0238622 s
# FOP updating mesh dependencies ... 1.8926e-05 s
# min/max(dweight) = 92.6486/99.9999
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x72944730ebb0>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 204/462
# min/max (error): 1%/1.08%
# min/max (start model): 362/362
# --------------------------------------------------------------------------------
# Calculating response for model: min = 362.412 max = 362.412
# Allocating memory for primary potential...... 0.000985065
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.347704s
# Response: min = 359.937 max = 362.884 mean = 362.259
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 92.6486/99.9999
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 418 x 235
# check Jacobian: wrong dimensions: (4320x780) should be (4283x235)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# inv.iter 0 ... chi² =  298.29
# --------------------------------------------------------------------------------
# inv.iter 1 ... S(8/8-std::mt): 0.0054597:time: 2.27203s
# sens sum: median = 1.0222 min = -1.19218 max = 1.69887
# ... 2.27649 s
# min data = 204.47 max data = 462.417 (4283)
# min error = 0.01 max error = 0.0107935 (4283)
# min response = 359.937 max response = 362.884 (4283)
# calc without reference model
# 0: rms/rrms(data, response) = 56.1621/20.1996%
# 0: chi^2(data, response, error, log) = 298.287
# 0: Phi = 1.27756e+06 + 0 * 20 = 1.27756e+06
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 4.5363 max = 10690.9
# Using existing primary potentials.
# Forward: time: 0.300869s
# Response: min = 124.255 max = 573.497 mean = 329.914
# Reciprocity rms(modelReciprocity) 0.943015%, max: 6.05135%
# 1: LS newModel: min = 4.5363; max = 10690.9
# 1: LS newResponse: min = 124.547; max = 571.94
# 1: rms/rrms(data, LS newResponse) = 66.5687/20.6574%
# 1: chi^2(data, LS newResponse, error, log) = 715.587
# 1: Phi = 3.06486e+06+215.055*20=3.06916e+06
# Performing line search with tau = 0.35
# Calculating response for model: min = 78.2218 max = 1184.78
# Using existing primary potentials.
# Forward: time: 0.287865s
# Response: min = 278.396 max = 436.865 mean = 353.647
# Reciprocity rms(modelReciprocity) 0.363678%, max: 2.43667%
# chi² =   98.76 (dPhi = 66.85%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... 1: Model: min = 78.2218; max = 1184.78
# 1: Response: min = 278.11; max = 436.608
# 1: rms/rrms(data, Response) = 31.6395/10.7578%
# 1: chi^2(data, Response, error, log) = 98.7614
# 1: Phi = 422995+26.3443*20=423522
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00155033:time: 2.32642s
# sens sum: median = 1.04052 min = -1.17353 max = 1.69461
# ... 2.33019 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 3.67289 max = 2937.73
# Using existing primary potentials.
# Forward: time: 0.286213s
# Response: min = 196.768 max = 529.941 mean = 342.913
# Reciprocity rms(modelReciprocity) 0.790335%, max: 5.57478%
# 2: LS newModel: min = 3.67289; max = 2937.73
# 2: LS newResponse: min = 197.862; max = 527.883
# 2: rms/rrms(data, LS newResponse) = 51.9296/15.0964%
# 2: chi^2(data, LS newResponse, error, log) = 300.524
# 2: Phi = 1.28714e+06+202.633*20=1.29119e+06
# Performing line search with tau = 0.26
# Calculating response for model: min = 37.2811 max = 1270.14
# Using existing primary potentials.
# Forward: time: 0.371236s
# Response: min = 264.907 max = 444.56 mean = 354.446
# Reciprocity rms(modelReciprocity) 0.489181%, max: 3.48568%
# chi² =   64.39 (dPhi = 34.65%) lam: 20.0
# --------------------------------------------------------------------------------
# 2: Model: min = 37.2811; max = 1270.14
# 2: Response: min = 264.629; max = 444.213
# 2: rms/rrms(data, Response) = 24.7639/8.64887%
# 2: chi^2(data, Response, error, log) = 64.3928
# 2: Phi = 275794+48.0091*20=276754
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00147954:time: 2.54254s
# sens sum: median = 1.07412 min = -1.22589 max = 2.21931
# ... 2.54626 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 10.7381 max = 2455.37
# Using existing primary potentials.
# Forward: time: 0.368689s
# Response: min = 188.636 max = 487.256 mean = 342.262
# Reciprocity rms(modelReciprocity) 0.825627%, max: 7.33045%
# 3: LS newModel: min = 10.7381; max = 2455.37
# 3: LS newResponse: min = 189.266; max = 487.202
# 3: rms/rrms(data, LS newResponse) = 27.292/7.60039%
# 3: chi^2(data, LS newResponse, error, log) = 60.9732
# 3: Phi = 261148+122.766*20=263604
# Performing line search with tau = 0.51
# Calculating response for model: min = 19.7607 max = 888.747
# Using existing primary potentials.
# Forward: time: 0.275419s
# Response: min = 225.148 max = 437.642 mean = 349.788
# Reciprocity rms(modelReciprocity) 0.650967%, max: 5.08446%
# chi² =   26.47 (dPhi = 58.54%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... 3: Model: min = 19.7607; max = 888.747
# 3: Response: min = 226.721; max = 435.605
# 3: rms/rrms(data, Response) = 17.57/5.24869%
# 3: chi^2(data, Response, error, log) = 26.4691
# 3: Phi = 113367+69.1738*20=114751
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00155342:time: 2.33594s
# sens sum: median = 1.07747 min = -1.16876 max = 3.81568
# ... 2.33936 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 11.6238 max = 2530.27
# Using existing primary potentials.
# Forward: time: 0.272637s
# Response: min = 187.812 max = 578.946 mean = 363.709
# Reciprocity rms(modelReciprocity) 0.904086%, max: 7.36794%
# 4: LS newModel: min = 11.6238; max = 2530.27
# 4: LS newResponse: min = 187.829; max = 578.204
# 4: rms/rrms(data, LS newResponse) = 47.4121/13.5827%
# 4: chi^2(data, LS newResponse, error, log) = 183.794
# 4: Phi = 787188+216.668*20=791521
# Performing line search with tau = 0.2
# chi² =   17.10 (dPhi = 34.77%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 5 ... Calculating response for model: min = 17.9885 max = 1066.36
# Using existing primary potentials.
# Forward: time: 0.277805s
# Response: min = 228.335 max = 445.985 mean = 353.964
# Reciprocity rms(modelReciprocity) 0.693742%, max: 5.52683%
# 4: Model: min = 17.9885; max = 1066.36
# 4: Response: min = 227.914; max = 444.12
# 4: rms/rrms(data, Response) = 12.611/4.31879%
# 4: chi^2(data, Response, error, log) = 17.0973
# 4: Phi = 73227.8+81.1358*20=74850.5
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00153914:time: 2.84825s
# sens sum: median = 1.09018 min = -1.24844 max = 4.33234
# ... 2.85306 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 19.3354 max = 1222.39
# Using existing primary potentials.
# Forward: time: 0.291117s
# Response: min = 199.221 max = 466.866 mean = 351.788
# Reciprocity rms(modelReciprocity) 0.854039%, max: 8.12394%
# chi² =    3.98 (dPhi = 74.56%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 6 ... 5: LS newModel: min = 19.3354; max = 1222.39
# 5: LS newResponse: min = 198.548; max = 465.624
# 5: rms/rrms(data, LS newResponse) = 7.29281/2.11544%
# 5: chi^2(data, LS newResponse, error, log) = 4.46077
# 5: Phi = 19105.5+104.978*20=21205
# Performing line search with tau = 0.88
# Calculating response for model: min = 19.1686 max = 1173.01
# Using existing primary potentials.
# Forward: time: 0.28284s
# Response: min = 202.601 max = 463.754 mean = 352.158
# Reciprocity rms(modelReciprocity) 0.833311%, max: 7.77048%
# 5: Model: min = 19.1686; max = 1173.01
# 5: Response: min = 201.952; max = 462.501
# 5: rms/rrms(data, Response) = 6.82032/2.00656%
# 5: chi^2(data, Response, error, log) = 3.97656
# 5: Phi = 17031.6+100.492*20=19041.4
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00139555:time: 3.20581s
# sens sum: median = 1.11658 min = -1.25451 max = 4.79237
# ... 3.21118 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 14.9458 max = 1299.28
# Using existing primary potentials.
# Forward: time: 0.293052s
# Response: min = 176.757 max = 471.113 mean = 343.462
# Reciprocity rms(modelReciprocity) 0.858014%, max: 8.94288%
# 6: LS newModel: min = 14.9458; max = 1299.28
# 6: LS newResponse: min = 177.998; max = 470.906
# 6: rms/rrms(data, LS newResponse) = 25.5206/7.67735%
# 6: chi^2(data, LS newResponse, error, log) = 61.6028
# 6: Phi = 263845+97.5519*20=265796
# Performing line search with tau = 0.09
# Calculating response for model: min = 18.8063 max = 1183.86
# Using existing primary potentials.
# Forward: time: 0.285581s
# Response: min = 200.837 max = 460.782 mean = 351.418
# Reciprocity rms(modelReciprocity) 0.834879%, max: 7.84389%
# chi² =    3.09 (dPhi = 20.29%) lam: 20.0
# --------------------------------------------------------------------------------
# 6: Model: min = 18.8063; max = 1183.86
# 6: Response: min = 200.17; max = 458.848
# 6: rms/rrms(data, Response) = 5.9272/1.76916%
# 6: chi^2(data, Response, error, log) = 3.08534
# 6: Phi = 13214.5+98.2126*20=15178.8
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00151386:time: 3.42494s
# sens sum: median = 1.1134 min = -1.24193 max = 4.74806
# ... 3.43026 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 15.2866 max = 1281.09
# Using existing primary potentials.
# Forward: time: 0.294549s
# Response: min = 194.14 max = 465.039 mean = 349.39
# Reciprocity rms(modelReciprocity) 0.871747%, max: 9.04435%
# 7: LS newModel: min = 15.2866; max = 1281.09
# 7: LS newResponse: min = 193.281; max = 463.415
# 7: rms/rrms(data, LS newResponse) = 10.9216/3.31338%
# 7: chi^2(data, LS newResponse, error, log) = 11.0006
# 7: Phi = 47115.4+96.1153*20=49037.7
# Performing line search with tau = 0.07
# Calculating response for model: min = 18.5355 max = 1190.42
# Using existing primary potentials.
# Forward: time: 0.328436s
# Response: min = 200.386 max = 460.55 mean = 351.328
# Reciprocity rms(modelReciprocity) 0.837054%, max: 7.90957%
# chi² =    2.94 (dPhi = 4.23%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 8 ... 7: Model: min = 18.5355; max = 1190.42
# 7: Response: min = 199.705; max = 458.62
# 7: rms/rrms(data, Response) = 5.75729/1.72678%
# 7: chi^2(data, Response, error, log) = 2.93913
# 7: Phi = 12588.3+97.4179*20=14536.7
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00179361:time: 3.26024s
# sens sum: median = 1.11353 min = -1.23774 max = 4.74453
# ... 3.2653 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 15.4264 max = 1276.44
# Using existing primary potentials.
# Forward: time: 0.283156s
# Response: min = 197.319 max = 467.209 mean = 351.094
# Reciprocity rms(modelReciprocity) 0.877733%, max: 9.09086%
# 8: LS newModel: min = 15.4264; max = 1276.44
# 8: LS newResponse: min = 196.461; max = 465.163
# 8: rms/rrms(data, LS newResponse) = 7.08614/2.15073%
# 8: chi^2(data, LS newResponse, error, log) = 4.59814
# 8: Phi = 19693.8+97.2413*20=21638.6
# Performing line search with tau = 0.16
# Calculating response for model: min = 17.9989 max = 1203.78
# Using existing primary potentials.
# Forward: time: 0.280934s
# Response: min = 199.914 max = 460.946 mean = 351.375
# Reciprocity rms(modelReciprocity) 0.842706%, max: 8.09004%
# chi² =    2.73 (dPhi = 6.20%) lam: 20.0
# --------------------------------------------------------------------------------
# 8: Model: min = 17.9989; max = 1203.78
# 8: Response: min = 199.205; max = 459.075
# 8: rms/rrms(data, Response) = 5.52326/1.66493%
# 8: chi^2(data, Response, error, log) = 2.73325
# 8: Phi = 11706.5+96.4494*20=13635.5
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00147723:time: 3.2554s
# sens sum: median = 1.11294 min = -1.23149 max = 4.76286
# ... 3.26051 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 15.9003 max = 1263.47
# Using existing primary potentials.
# Forward: time: 0.322453s
# Response: min = 201.269 max = 469.999 mean = 353.232
# Reciprocity rms(modelReciprocity) 0.887727%, max: 9.22511%
# 9: LS newModel: min = 15.9003; max = 1263.47
# 9: LS newResponse: min = 200.381; max = 468.067
# 9: rms/rrms(data, LS newResponse) = 5.09149/1.50898%
# 9: chi^2(data, LS newResponse, error, log) = 2.23128
# 9: Phi = 9556.58+99.9309*20=11555.2
# Performing line search with tau = 0.74
# Calculating response for model: min = 16.4212 max = 1247.67
# Using existing primary potentials.
# Forward: time: 0.301687s
# Response: min = 200.904 max = 467.429 mean = 352.809
# Reciprocity rms(modelReciprocity) 0.874846%, max: 8.92453%
# chi² =    2.12 (dPhi = 19.03%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 10 ... 9: Model: min = 16.4212; max = 1247.67
# 9: Response: min = 200.063; max = 465.556
# 9: rms/rrms(data, Response) = 4.92787/1.46869%
# 9: chi^2(data, Response, error, log) = 2.11903
# 9: Phi = 9075.82+98.2293*20=11040.4
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00142676:time: 3.30927s
# chi² =    1.92 (dPhi = 7.74%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 11 ... sens sum: median = 1.11433 min = -1.22182 max = 4.95005
# ... 3.31425 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 20.025 max = 1277.25
# Using existing primary potentials.
# Forward: time: 0.293507s
# Response: min = 197.646 max = 460.841 mean = 350.517
# Reciprocity rms(modelReciprocity) 0.905663%, max: 9.80423%
# 10: LS newModel: min = 20.025; max = 1277.25
# 10: LS newResponse: min = 196.819; max = 458.927
# 10: rms/rrms(data, LS newResponse) = 6.12775/1.79455%
# 10: chi^2(data, LS newResponse, error, log) = 3.18297
# 10: Phi = 13632.7+100.854*20=15649.8
# Performing line search with tau = 0.27
# Calculating response for model: min = 17.3249 max = 1255.59
# Using existing primary potentials.
# Forward: time: 0.284148s
# Response: min = 200.094 max = 465.612 mean = 352.247
# Reciprocity rms(modelReciprocity) 0.882678%, max: 9.16054%
# 10: Model: min = 17.3249; max = 1255.59
# 10: Response: min = 199.256; max = 463.725
# 10: rms/rrms(data, Response) = 4.69633/1.39612%
# 10: chi^2(data, Response, error, log) = 1.91746
# 10: Phi = 8212.5+98.6564*20=10185.6
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00111639:time: 3.23734s
# sens sum: median = 1.11401 min = -1.21343 max = 4.73711
# ... 3.24236 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 19.4748 max = 1306.89
# Using existing primary potentials.
# Forward: time: 0.323913s
# Response: min = 198.992 max = 466.986 mean = 352.889
# Reciprocity rms(modelReciprocity) 0.910261%, max: 9.87466%
# 11: LS newModel: min = 19.4748; max = 1306.89
# 11: LS newResponse: min = 198.122; max = 464.891
# 11: rms/rrms(data, LS newResponse) = 4.7375/1.38972%
# 11: chi^2(data, LS newResponse, error, log) = 1.89604
# 11: Phi = 8120.74+101.059*20=10141.9
# Performing line search with tau = 0.52
# Calculating response for model: min = 18.4114 max = 1282.01
# Using existing primary potentials.
# Forward: time: 0.326808s
# Response: min = 199.541 max = 466.271 mean = 352.603
# Reciprocity rms(modelReciprocity) 0.896538%, max: 9.53038%
# chi² =    1.84 (dPhi = 2.90%) lam: 20.0
# --------------------------------------------------------------------------------
# inv.iter 12 ... 11: Model: min = 18.4114; max = 1282.01
# 11: Response: min = 198.686; max = 464.277
# 11: rms/rrms(data, Response) = 4.63121/1.36953%
# 11: chi^2(data, Response, error, log) = 1.84337
# 11: Phi = 7895.16+99.7502*20=9890.17
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00211045:time: 3.36906s
# sens sum: median = 1.11556 min = -1.21466 max = 4.52004
# ... 3.37374 s
# solve CGLSCDWWtrans with lambda = 20
# Calculating response for model: min = 18.6147 max = 1289.25
# Using existing primary potentials.
# Forward: time: 0.285535s
# Response: min = 198.336 max = 463.533 mean = 351.498
# Reciprocity rms(modelReciprocity) 0.912199%, max: 9.99604%
# 12: LS newModel: min = 18.6147; max = 1289.25
# 12: LS newResponse: min = 197.474; max = 461.528
# 12: rms/rrms(data, LS newResponse) = 5.47042/1.59683%
# 12: chi^2(data, LS newResponse, error, log) = 2.51293
# 12: Phi = 10762.9+100.606*20=12775
# Performing line search with tau = 0.2
# chi² =    1.80 (dPhi = 1.97%) lam: 20.0
# ################################################################################
# #                Abort criterion reached: dPhi = 1.97 (< 2.0%)                 #
# ################################################################################
# Calculating response for model: min = 18.4519 max = 1283.45
# Using existing primary potentials.
# Forward: time: 0.293936s
# Response: min = 199.303 max = 465.715 mean = 352.385
# Reciprocity rms(modelReciprocity) 0.899492%, max: 9.62301%
# 12: Model: min = 18.4519; max = 1283.45
# 12: Response: min = 198.446; max = 463.72
# 12: rms/rrms(data, Response) = 4.5634/1.352%
# 12: chi^2(data, Response, error, log) = 1.79733
# 12: Phi = 7697.94+99.8563*20=9695.07

# %% [markdown]
# ## Visualization
# You can of course get access to mesh and model and plot them for your own.
# Note that the cells of the parametric domain of your mesh might be in
# a different order than the values in the model array if regions are used.
# The manager can help to permutate them into the right order.

# %%
modelPD = mgr.paraModel(model)  # do the mapping
#pg.show(mgr.paraDomain, modelPD, label='Model', cMap='Spectral_r', logScale=True)

pg.info('Inversion stopped with chi² = {0:.3}'.format(mgr.fw.chi2()))

fig, (ax1, ax2) = plt.subplots(2,1, sharex=True, sharey=True, figsize=(7,4.2))

pg.show(mesh, rhomap, ax=ax1, hold=True, cMap="Spectral_r", logScale=False,
        orientation="vertical", cMin=20, cMax=400
       )
pg.show(meshPD, inv, ax=ax2, hold=True, cMap="Spectral_r", logScale=True,
        orientation="vertical", #cMin=20, cMax=400
       )
#mgr.showResult(ax=ax3, cMin=20, cMax=500,
               #orientation="vertical")

labels = ["True model", #"Inversion unstructured mesh", "Inversion regular grid"
         "Inversion with "+seq_name]
for ax, label in zip([ax1, ax2], labels):
    ax.set_xlim(mgr.paraDomain.xmin(), mgr.paraDomain.xmax())
    ax.set_ylim(mgr.paraDomain.ymin(), mgr.paraDomain.ymax())
    ax.set_title(label)
fig.savefig(seq_name+'_2D.png', dpi=200, bbox_inches='tight', transparent=True)
# Out:
# 04/08/25 - 11:57:15 - pyGIMLi - INFO - Inversion stopped with chi² = 1.8
