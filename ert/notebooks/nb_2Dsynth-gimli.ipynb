# %% [markdown]
# # 2D ERT modelling and inversion

# %%
import matplotlib.pyplot as plt
import numpy as np

import pygimli as pg
import pygimli.meshtools as mt
from pygimli.physics import ert
from pygimli.viewer.mpl import drawSensors

# %% [markdown]
# ## Geometry definition
# Create geometry definition for the modelling domain. ``worldMarker=True``
# indicates the default boundary conditions for the ERT

# %%
world = mt.createWorld(start=[-50, 0], end=[90, -50], marker=1, #layers=[-1, -5],
                       worldMarker=True)
pg.show(world)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>, None)

# %% [markdown]
# Create some heterogeneous anomaly and merge them into a Piecewise Linear Complex (PLC)

# %%
c = mt.createCircle(pos=[10, -5.], radius=[3, 1.5], marker=2, boundaryMarker=10, area=0.1)
r = mt.createRectangle(pos=[35, -7], size=[4.0, 4.0], marker=3, area=0.1)

geom = world + c + r
pg.show(geom)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>, None)

# %% [markdown]
# ## Synthetic data generation
# Create a Dipole Dipole ('dd') measuring scheme with 48 electrodes.

# %%
n_elecs = 48
spacing = 1.0  # m
scheme = ert.createData(elecs=np.linspace(start=0, stop=(n_elecs*spacing)-spacing, num=n_elecs), schemeName='dd')

# %% [raw]
# seq_name = 'dd48_0_4'
# scheme = pg.load('data/'+seq_name+'.dat') # pick up the scheme to reproduce
# #elecs2D = np.genfromtxt('../../data/2d/elecs72surf.csv', delimiter=",",skip_header=1)
# #data2D = pg.load(datadir + '../../data/2d/2Ddata.dat') # pick up the scheme to reproduce
# print(scheme)

# %% [markdown]
# Put all electrode (aka sensors) positions into the PLC to enforce mesh
# refinement. Due to experience, its convenient to add further refinement
# nodes in a distance of 10% of electrode spacing to achieve sufficient
# numerical accuracy.

# %%
for p in scheme.sensors():
    geom.createNode(p)
    geom.createNode(p - [0, 0.1])

# Create a mesh for the finite element modelling with appropriate mesh quality.
mesh = mt.createMesh(geom, quality=34)
pg.show(mesh)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>, None)

# %%
# Create a map to set resistivity values in the appropriate regions
# [[regionNumber, resistivity], [regionNumber, resistivity], [...]
rhomap = [[1, 200.],
          [2, 20.],
          [3, 20000.],
         ]

# Take a look at the mesh and the resistivity distribution
fig, ax = pg.plt.subplots()
pg.show(mesh, ax=ax, data=rhomap, label=pg.unit('res'), showMesh=True, logScale=True)
drawSensors(ax, scheme.sensors(), diam=.5, color='m')
ax.set_ylim(-20,1)
ax.set_xlim(-5,47+5)
fig.tight_layout()
fig.savefig('../figures/fwdmodel2D.png', dpi=150, bbox_inches='tight')

# %% [markdown]
# Perform the modelling with the mesh and the measuring scheme itself
# and return a data container with apparent resistivity values,
# geometric factors and estimated data errors specified by the noise setting.
# The noise is also added to the data. Here 1% plus 1µV.
# Note, we force a specific noise seed as we want reproducable results for
# testing purposes.

# %%
data = ert.simulate(mesh, scheme=scheme, res=rhomap, noiseLevel=1,
                    noiseAbs=1e-6, seed=1337)

pg.info(np.linalg.norm(data['err']), np.linalg.norm(data['rhoa']))
pg.info('Simulated data', data)
pg.info('The data contains:', data.dataMap().keys())

pg.info('Simulated rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))
pg.info('Selected data noise %(min/max)', min(data['err'])*100, max(data['err'])*100)
# Out:
# ModellingBase::setMesh() copying new mesh ... Found datafile: 48 electrodes
# Found: 48 free-electrodes
# rMin = 0.5, rMax = 94
# NGauLeg + NGauLag for inverse Fouriertransformation: 13 + 4
# Found non-Neumann domain
# 0.0335874 s
# FOP updating mesh dependencies ... 5.585e-06 s
# relativeError set to a value > 0.5 .. assuming this is a percentage Error level dividing them by 100
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - Data error estimate (min:max)  0.01000009393323961 : 0.011625865457318215
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - 0.327974733105717 6294.559672538856
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - Simulated data Data: Sensors: 48 data: 1035, nonzero entries: ['a', 'b', 'err', 'k', 'm', 'n', 'rhoa', 'valid']
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - The data contains: ['a', 'b', 'err', 'i', 'ip', 'iperr', 'k', 'm', 'n', 'r', 'rhoa', 'u', 'valid']
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - Simulated rhoa (min/max) 134.50428288296908 251.140934250215
# 29/08/25 - 18:06:18 - pyGIMLi - INFO - Selected data noise %(min/max) 1.000009393323961 1.1625865457318216
# Calculating response for model: min = 20 max = 20000
# Allocating memory for primary potential...... 0.00727971
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.325237s
# Response: min = 136.203 max = 249.709 mean = 193.701
# Reciprocity rms(modelReciprocity) 0.115533%, max: 0.64721%

# %% [markdown]
# Optional: you can filter all values and tokens in the data container.
# Its possible that there are some negative data values due to noise and
# huge geometric factors. So we need to remove them.

# %%
data.remove(data['rhoa'] < 0)
pg.info('Filtered rhoa (min/max)', min(data['rhoa']), max(data['rhoa']))

# You can save the data for further use
data.save('../data/dd48_fwd.dat')

# You can take a look at the data
ert.show(data)
# Out:
# 29/08/25 - 18:06:20 - pyGIMLi - INFO - Filtered rhoa (min/max) 134.50428288296908 251.140934250215
# (<Axes: >, <matplotlib.colorbar.Colorbar at 0x78a32c3bf8d0>)

# %% [markdown]
# ## Inversion with the ERTManager
# Initialize the ERTManager, e.g. with a data container or a filename.

# %%
mgr = ert.ERTManager('../data/dd48_fwd.dat')
inv = mgr.invert(lam=50, verbose=True)
#np.testing.assert_approx_equal(mgr.inv.chi2(), 0.7, significant=1)
# Out:
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Found 2 regions.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Found 2 regions.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2222 Cells: 4164 Boundaries: 3262
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Use median(data values)=199.622783916353
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Created startmodel from forward operator:780, min/max=199.622784/199.622784
# 29/08/25 - 18:06:23 - pyGIMLi - INFO - Starting inversion.
# Constructing Delaunay triangulation by divide-and-conquer method.
# Delaunay milliseconds:  0
# Recovering segments in Delaunay triangulation.
# Segment milliseconds:  0
# Removing unwanted triangles.
# Spreading regional attributes and area constraints.
# Hole milliseconds:  0
# Adding Steiner points to enforce quality.
# Quality milliseconds:  0
#
# Writing vertices.
# Writing triangles.
# Writing segments.
# Writing edges.
#
# Output milliseconds:  0
# Total running milliseconds:  0
#
# Statistics:
#
#   Input vertices: 103
#   Input segments: 104
#   Input holes: 0
#
#   Mesh vertices: 591
#   Mesh triangles: 1041
#   Mesh edges: 1631
#   Mesh exterior boundary edges: 139
#   Mesh interior boundary edges: 20
#   Mesh subsegments (constrained edges): 159
#
# min/max(dweight) = 86.0151/99.9991
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x78a327b722a0>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 134/251
# min/max (error): 1%/1.16%
# min/max (start model): 200/200
# --------------------------------------------------------------------------------
# Calculating response for model: min = 199.623 max = 199.623
# Allocating memory for primary potential...... 0.00112809
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.357738s
# Response: min = 199.03 max = 199.883 mean = 199.552
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 86.0151/99.9991
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 1110 x 780
# check Jacobian: wrong dimensions: (0x0) should be (1035x780)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# inv.iter 0 ... chi² =  236.22S(8/8-std::mt): 0.00607595:time: 1.19332s
#
# --------------------------------------------------------------------------------
# inv.iter 1 ... sens sum: median = 1.06341 min = 0.954188 max = 1.48432
# ... 1.1957 s
# min data = 134.504 max data = 251.141 (1035)
# min error = 0.0100001 max error = 0.0116259 (1035)
# min response = 199.03 max response = 199.883 (1035)
# calc without reference model
# 0: rms/rrms(data, response) = 28.7158/17.6232%
# 0: chi^2(data, response, error, log) = 236.22
# 0: Phi = 244488 + 0 * 50 = 244488
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 36.1454 max = 484.532
# Using existing primary potentials.
# Forward: time: 0.291933s
# Response: min = 131.489 max = 247.357 mean = 192.054
# Reciprocity rms(modelReciprocity) 0.196317%, max: 0.409093%
# 1: LS newModel: min = 36.1454; max = 484.532
# 1: LS newResponse: min = 131.669; max = 247.316
# 1: rms/rrms(data, LS newResponse) = 3.34831/1.90586%
# 1: chi^2(data, LS newResponse, error, log) = 3.54504
# 1: Phi = 3669.12+11.7995*50=4259.09
# Performing line search with tau = 0.93
# Calculating response for model: min = 40.7384 max = 455.37
# Using existing primary potentials.
# Forward: time: 0.456909s
# Response: min = 135.686 max = 243.976 mean = 192.625
# Reciprocity rms(modelReciprocity) 0.180928%, max: 0.38076%
# 1: Model: min = 40.7384; max = 455.37
# 1: Response: min = 135.854; max = 243.94
# 1: rms/rrms(data, Response) = 2.9264/1.45545%
# 1: chi^2(data, Response, error, log) = 2.04312
# 1: Phi = 2114.62+10.2054*50=2624.89
# chi² =    2.04 (dPhi = 98.93%) lam: 50.0
# --------------------------------------------------------------------------------
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00180516:time: 1.35602s
# sens sum: median = 1.11749 min = 0.954175 max = 1.61548
# ... 1.35842 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 47.8038 max = 530.308
# Using existing primary potentials.
# Forward: time: 0.337284s
# Response: min = 134.34 max = 248.722 mean = 192.928
# Reciprocity rms(modelReciprocity) 0.187951%, max: 0.352548%
# 2: LS newModel: min = 47.8038; max = 530.308
# 2: LS newResponse: min = 134.696; max = 248.679
# 2: rms/rrms(data, LS newResponse) = 2.33593/1.23668%
# 2: chi^2(data, LS newResponse, error, log) = 1.42816
# 2: Phi = 1478.15+9.62841*50=1959.57
# Performing line search with tau = 0.78
# Calculating response for model: min = 46.151 max = 512.828
# Using existing primary potentials.
# Forward: time: 0.303482s
# Response: min = 135.108 max = 247.683 mean = 192.868
# Reciprocity rms(modelReciprocity) 0.186176%, max: 0.356414%
# chi² =    1.36 (dPhi = 27.89%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 46.151; max = 512.828
# 2: Response: min = 135.46; max = 247.642
# 2: rms/rrms(data, Response) = 2.29818/1.20142%
# 2: chi^2(data, Response, error, log) = 1.36046
# 2: Phi = 1408.08+9.69241*50=1892.7
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00123673:time: 1.21162s
# sens sum: median = 1.12211 min = 0.954063 max = 1.59036
# ... 1.21467 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 47.2733 max = 524.902
# Using existing primary potentials.
# Forward: time: 0.300235s
# Response: min = 135.162 max = 248.314 mean = 192.994
# Reciprocity rms(modelReciprocity) 0.184906%, max: 0.354573%
# Performing line search with tau = 1
# 3: Model: min = 47.2733; max = 524.902
# 3: Response: min = 135.509; max = 248.289
# 3: rms/rrms(data, Response) = 2.09629/1.08836%
# 3: chi^2(data, Response, error, log) = 1.1282
# 3: Phi = 1167.69+9.66632*50=1651
# chi² =    1.13 (dPhi = 12.77%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000991787:time: 1.25396s
# sens sum: median = 1.12312 min = 0.954062 max = 1.59378
# ... 1.25704 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 47.2522 max = 527.094
# Using existing primary potentials.
# Forward: time: 0.296045s
# Response: min = 136.24 max = 249.137 mean = 193.557
# Reciprocity rms(modelReciprocity) 0.183302%, max: 0.358211%
# 4: LS newModel: min = 47.2522; max = 527.094
# 4: LS newResponse: min = 136.403; max = 249.116
# 4: rms/rrms(data, LS newResponse) = 1.93522/1.00369%
# 4: chi^2(data, LS newResponse, error, log) = 0.960033
# 4: Phi = 993.634+9.68772*50=1478.02
# Performing line search with tau = 0.94
# Calculating response for model: min = 47.2535 max = 526.962
# Using existing primary potentials.
# Forward: time: 0.328989s
# Response: min = 136.208 max = 249.088 mean = 193.523
# Reciprocity rms(modelReciprocity) 0.183396%, max: 0.357848%
# chi² =    0.96 (dPhi = 10.52%) lam: 50.0
#
#
# ################################################################################
# #                  Abort criterion reached: chi² <= 1 (0.96)                   #
# ################################################################################
# 4: Model: min = 47.2535; max = 526.962
# 4: Response: min = 136.371; max = 249.066
# 4: rms/rrms(data, Response) = 1.93476/1.00298%
# 4: chi^2(data, Response, error, log) = 0.959447
# 4: Phi = 993.027+9.68634*50=1477.34

# %% [raw]
# # ------------------------
# # 6. Forward operator e Jacobian
# # ------------------------
# fop = ert.ERTModelling()
# fop.setMesh(mesh)
# fop.setData(data)
#
# # Sensitivity matrix coherent with rhomap
# model = pg.solver.parseMapToCellArray(rhomap, mesh)
# fop.createJacobian(model)
# J = fop.jacobian() # sensitivity matrix [n_misure x n_celle]
#
# print("Jacobian shape (sensitivity):", J.shape)
#
# # ------------------------
# # 7. Covariance matrix of measurements
# # ------------------------
# # costruiamo la covarianza tra righe (misure) usando similarità coseno
# cov_matrix = cosine_similarity(J)  # matrice simmetrica [n_misure x n_misure]
#
# plt.figure(figsize=(5,5))
# plt.imshow(cov_matrix, cmap='viridis', vmin=0)
# plt.colorbar(label='Cosine Similarity', shrink=.5)
# plt.title("Covariance matrix")
# plt.xlabel("measure")
# plt.ylabel("measure")
# plt.tight_layout()
# plt.show()

# %% [markdown]
# Run the inversion with the preset data. The Inversion mesh will be created
# with default settings.

# %% [markdown]
# Let the ERTManger show you the model of the last successful run and how it
# fits the data. Shows data, model response, and model.

# %%
mgr.showResultAndFit()
meshPD = pg.Mesh(mgr.paraDomain) # Save copy of para mesh for plotting later

# %% [markdown]
# You can also provide your own mesh (e.g., a structured grid if you like them)
# Note, that x and y coordinates needs to be in ascending order to ensure that
# all the cells in the grid have the correct orientation, i.e., all cells need
# to be numbered counter-clockwise and the boundary normal directions need to
# point outside.

# %%
inversionDomain = pg.createGrid(x=np.linspace(start=0, stop=47*1, num=48),
                                y=-pg.cat([0], pg.utils.grange(0.5, 15, n=5))[::-1],
                                marker=2)

# %% [markdown]
# ## Inversion with custom mesh
# The inversion domain for ERT problems needs a boundary that represents the
# far regions in the subsurface of the halfspace.
# Give a cell marker lower than the marker for the inversion region, the lowest
# cell marker in the mesh will be the inversion boundary region by default.

# %%
grid = pg.meshtools.appendTriangleBoundary(inversionDomain, marker=1,
                                           xbound=50, ybound=50)
pg.show(grid, markers=True)
# Out:
# (<Axes: xlabel='$x$ in m', ylabel='Depth in m'>,
#  <matplotlib.colorbar.Colorbar at 0x78a325e50c90>)

# %%
data.remove(data["rhoa"] <= 140)
data.remove(data["rhoa"] >= 240)
data.removeInvalid()
data.removeUnusedSensors()

# plot
fig, ax = plt.subplots(figsize=(6, 3))
ax.scatter(np.arange(1, len(data['a']) + 1), data["rhoa"], color='red', s=10)
ax.set_ylabel('Apparent Resistivity (ohm.m)')
ax.set_xlabel('measure n.')
fig.suptitle(f'Quadrupoles n :{len(data["rhoa"])}')
# Out:
# Text(0.5, 0.98, 'Quadrupoles n :984')

# %% [markdown]
# The Inversion can be called with data and mesh as argument as well

# %%
model = mgr.invert(data, mesh=grid, lam=50, verbose=True)
# Out:
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Found 2 regions.
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - (ERTModelling) Region with smallest marker (1) set to background.
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Creating forward mesh from region infos.
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Creating refined mesh (H2) to solve forward task.
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Mesh for forward task: Mesh: Nodes: 2035 Cells: 2980 Boundaries: 2544
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Use median(data values)=199.59382922490903
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Created startmodel from forward operator:235, min/max=199.593829/199.593829
# 29/08/25 - 18:06:39 - pyGIMLi - INFO - Starting inversion.
# Found datafile: 48 electrodes
# Found: 48 node-electrodes
# Found non-Neumann domain
#  updateDataDependency:: cleaning primpot
# Reset region parameter
# RegionManager copying mesh ...0.00447482 s
# create NeighborInfos ... 1.923e-05 s
# analysing mesh ... 2 regions.
# creating para domain ... 0.00169912 s
# creating para domain ... 0.00245197 s
# ModellingBase::setMesh() copying new mesh ... Found datafile: 48 electrodes
# Found: 48 free-electrodes
# Found non-Neumann domain
# 0.0348812 s
# FOP updating mesh dependencies ... 2.5606e-05 s
# ModellingBase::setMesh() copying new mesh ... 0.016908 s
# FOP updating mesh dependencies ... 2.1518e-05 s
# min/max(dweight) = 86.0151/99.9991
# fop: <pygimli.physics.ert.ertModelling.ERTModelling object at 0x78a327b722a0>
# Data transformation: Logarithmic LU transform, lower bound 0.0, upper bound 0.0
# Model transformation: Logarithmic transform
# min/max (data): 140/240
# min/max (error): 1%/1.16%
# min/max (start model): 200/200
# --------------------------------------------------------------------------------
# Calculating response for model: min = 199.594 max = 199.594
# Allocating memory for primary potential...... 0.000934135
#
# No primary potential for secondary field calculation. Calculating analytically...
# Forward: time: 0.322452s
# Response: min = 199.001 max = 199.854 mean = 199.52
# Reciprocity rms(modelReciprocity) 0%, max: 0%
# min/max(dweight) = 86.0151/99.9991
# Building constraints matrix
# constraint matrix of size(nBounds x nModel) 418 x 235
# check Jacobian: wrong dimensions: (1035x780) should be (984x235)  force: 1
# jacobian size invalid, forced recalc: 1
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# inv.iter 0 ... chi² =  204.91
# --------------------------------------------------------------------------------
# inv.iter 1 ... S(8/8-std::mt): 0.00106284:time: 0.488574s
# sens sum: median = 1.09736 min = 1.00017 max = 1.7321
# ... 0.489421 s
# min data = 140.015 max data = 239.799 (984)
# min error = 0.0100001 max error = 0.0116259 (984)
# min response = 199.001 max response = 199.854 (984)
# calc without reference model
# 0: rms/rrms(data, response) = 26.7565/16.3275%
# 0: chi^2(data, response, error, log) = 204.911
# 0: Phi = 201633 + 0 * 50 = 201633
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 23.0799 max = 453.744
# Using existing primary potentials.
# Forward: time: 0.284766s
# Response: min = 134.222 max = 249.874 mean = 192.323
# Reciprocity rms(modelReciprocity) 0.829313%, max: 3.13492%
# 1: LS newModel: min = 23.0799; max = 453.744
# 1: LS newResponse: min = 134.149; max = 248.877
# 1: rms/rrms(data, LS newResponse) = 5.88036/3.24244%
# 1: chi^2(data, LS newResponse, error, log) = 10.2972
# 1: Phi = 10132.4+30.9268*50=11678.7
# Performing line search with tau = 0.89
# Calculating response for model: min = 29.2614 max = 414.551
# Using existing primary pochi² =    5.78 (dPhi = 96.57%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 2 ... tentials.
# Forward: time: 0.280329s
# Response: min = 140.972 max = 243.918 mean = 193.308
# Reciprocity rms(modelReciprocity) 0.744151%, max: 2.78872%
# 1: Model: min = 29.2614; max = 414.551
# 1: Response: min = 140.887; max = 243.045
# 1: rms/rrms(data, Response) = 4.52881/2.47891%
# 1: chi^2(data, Response, error, log) = 5.78331
# 1: Phi = 5690.78+24.4972*50=6915.64
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000335479:time: 0.498662s
# sens sum: median = 1.19214 min = 0.961908 max = 1.93618
# ... 0.499507 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 30.8273 max = 485.65
# Using existing primary potentials.
# Forward: time: 0.319993s
# Response: min = 134.178 max = 239.392 mean = 191.427
# Reciprocity rms(modelReciprocity) 0.772202%, max: 3.44136%
# 2: LS newModel: min = 30.8273; max = 485.65
# 2: LS newResponse: min = 134.74; max = 238.451
# 2: rms/rrms(data, LS newResponse) = 4.16975/2.28574%
# 2: chi^2(data, LS newResponse, error, log) = 4.93753
# 2: Phi = 4858.53+27.7977*50=6248.41
# Performing line search with tau = 0.56
# Calculating response for model: min = 30.1282 max = 452.976
# Using existing primary potentials.
# Forward: time: 0.291044s
# Response: min = 139.014 max = 241.406 mean = 192.337
# Reciprocity rms(modelReciprocity) 0.753201%, max: 2.92713%
# chi² =    3.69 (dPhi = 28.72%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 3 ... 2: Model: min = 30.1282; max = 452.976
# 2: Response: min = 139.626; max = 240.494
# 2: rms/rrms(data, Response) = 3.6091/1.96423%
# 2: chi^2(data, Response, error, log) = 3.68737
# 2: Phi = 3628.37+26.0251*50=4929.62
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000507942:time: 0.529269s
# sens sum: median = 1.19009 min = 0.963308 max = 1.9061
# ... 0.530491 s
# solve CGLSCDWWtrans with lambda = 50
# chi² =    2.80 (dPhi = 15.88%) lam: 50.0
# --------------------------------------------------------------------------------
# inv.iter 4 ... Calculating response for model: min = 30.6491 max = 482.008
# Using existing primary potentials.
# Forward: time: 0.333024s
# Response: min = 136.792 max = 239.968 mean = 192.162
# Reciprocity rms(modelReciprocity) 0.791145%, max: 3.72189%
# Performing line search with tau = 1
# 3: Model: min = 30.6491; max = 482.008
# 3: Response: min = 137.396; max = 239.001
# 3: rms/rrms(data, Response) = 3.17134/1.70716%
# 3: chi^2(data, Response, error, log) = 2.80205
# 3: Phi = 2757.21+27.7896*50=4146.69
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.000434468:time: 0.544436s
# sens sum: median = 1.19039 min = 0.960995 max = 1.93188
# ... 0.545672 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 31.1892 max = 482.43
# Using existing primary potentials.
# Forward: time: 0.272375s
# Response: min = 140.128 max = 242.455 mean = 193.572
# Reciprocity rms(modelReciprocity) 0.804221%, max: 4.162%
# chi² =    1.75 (dPhi = 24.98%) lam: 50.0
# --------------------------------------------------------------------------------
# Performing line search with tau = 0.95
# 4: Model: min = 31.1892; max = 482.43
# 4: Response: min = 140.745; max = 241.461
# 4: rms/rrms(data, Response) = 2.52863/1.34493%
# 4: chi^2(data, Response, error, log) = 1.74755
# 4: Phi = 1719.59+27.8227*50=3110.73
# Calculating Jacobian matrix (forced=1)...Using existing subpotentials for createJacobian.
# S(8/8-std::mt): 0.00042222:time: 0.561659s
# sens sum: median = 1.18942 min = 0.961396 max = 1.96464
# ... 0.562567 s
# solve CGLSCDWWtrans with lambda = 50
# Calculating response for model: min = 31.6507 max = 483.702
# Using existing primary potentials.
# Forward: time: 0.273399s
# Response: min = 140.153 max = 242.916 mean = 193.858
# Reciprocity rms(modelReciprocity) 0.804407%, max: 4.13546%
# 5: LS newModel: min = 31.6507; max = 483.702
# 5: LS newResponse: min = 140.752; max = 241.919
# 5: rms/rrms(data, LS newResponse) = 2.52442/1.35066%
# 5: chi^2(data, LS newResponse, error, log) = 1.75392
# 5: Phi = 1725.86+27.857*50=3118.71
# Performing line search with tau = 0.41
# Calculating response for model: min = 31.3776 max = 482.951
# Using existing primary potentials.
# Forward: time: 0.263056s
# Response: min = 140.139 max = 242.645 mean = 193.69
# Reciprocity rms(modelReciprocity) 0.804277%, max: 4.1511%
# chi² =    1.74 (dPhi = 0.25%) lam: 50.0
# ################################################################################
# #                Abort criterion reached: dPhi = 0.25 (< 2.0%)                 #
# ################################################################################
# 5: Model: min = 31.3776; max = 482.951
# 5: Response: min = 140.749; max = 241.65
# 5: rms/rrms(data, Response) = 2.51981/1.34304%
# 5: chi^2(data, Response, error, log) = 1.73914
# 5: Phi = 1711.31+27.8321*50=3102.91

# %% [markdown]
# ## Visualization
# You can of course get access to mesh and model and plot them for your own.
# Note that the cells of the parametric domain of your mesh might be in
# a different order than the values in the model array if regions are used.
# The manager can help to permutate them into the right order.

# %%
modelPD = mgr.paraModel(model)  # do the mapping
#pg.show(mgr.paraDomain, modelPD, label='Model', cMap='Spectral_r', logScale=True)

pg.info('Inversion stopped with chi² = {0:.3}'.format(mgr.fw.chi2()))

fig, (ax1, ax2) = plt.subplots(2,1, sharex=True, sharey=True, figsize=(7,4.2))

pg.show(mesh, rhomap, ax=ax1, hold=True, cMap="Spectral_r", logScale=True,
        orientation="vertical", #cMin=20, cMax=400
       )
pg.show(meshPD, inv, ax=ax2, hold=True, cMap="Spectral_r", logScale=True,
        orientation="vertical", #cMin=20, cMax=400
       )
#mgr.showResult(ax=ax3, cMin=20, cMax=500,
               #orientation="vertical")

labels = ["True model", #"Inversion unstructured mesh", "Inversion regular grid"
         "Inversion"]
for ax, label in zip([ax1, ax2], labels):
    ax.set_xlim(mgr.paraDomain.xmin(), mgr.paraDomain.xmax())
    ax.set_ylim(mgr.paraDomain.ymin(), mgr.paraDomain.ymax())
    ax.set_title(label)

fig.savefig('../figures/2Dmodel.png', dpi=150, bbox_inches='tight', transparent=False)
# Out:
# 29/08/25 - 18:07:53 - pyGIMLi - INFO - Inversion stopped with chi² = 1.74
